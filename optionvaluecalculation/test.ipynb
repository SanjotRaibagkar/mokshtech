# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import Future_OI as FI

# %%
FI.test()
# Out:
#                 F_OI     Close
# 2018-07-11  0.472272  0.906801
# 2018-07-12  0.556436  0.995706
# 2018-07-13  0.567811  1.000000
