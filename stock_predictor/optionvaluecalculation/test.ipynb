# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

# %%
import Future_OI as FI

# %%
FI.test()
# Out:
#                 F_OI     Close
# 2018-06-26  0.653837  0.888364
# 2018-06-27  0.729252  0.754529
# 2018-06-28  0.833317  0.635589
